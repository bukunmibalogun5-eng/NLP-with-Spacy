# %% [markdown]
# <a href="https://colab.research.google.com/github/bukunmibalogun5-eng/NLP-with-Spacy/blob/main/NLP_with_Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 38.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
with open("/content/wiki_us.txt","r") as f:
  text=f.read()

# %%
print(text)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America. It consists of 50 states, a federal district, five major unincorporated territories, 326 Indian reservations, and some minor possessions.[j] At 3.8 million square miles (9.8 million square kilometers), it is the world's third- or fourth-largest country by total area.[d] The United States shares significant land borders with Canada to the north and Mexico to the south, as well as limited maritime borders with the Bahamas, Cuba, and Russia.[22] With a population of more than 331 million people, it is the third most populous country in the world. The national capital is Washington, D.C., and the most populous city is New York.
#
# ...

# %%
doc=nlp(text)

# %%
print(doc)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America. It consists of 50 states, a federal district, five major unincorporated territories, 326 Indian reservations, and some minor possessions.[j] At 3.8 million square miles (9.8 million square kilometers), it is the world's third- or fourth-largest country by total area.[d] The United States shares significant land borders with Canada to the north and Mexico to the south, as well as limited maritime borders with the Bahamas, Cuba, and Russia.[22] With a population of more than 331 million people, it is the third most populous country in the world. The national capital is Washington, D.C., and the most populous city is New York.
#
# ...

# %%
print(len(text))
print(len(doc))
# Out:
# 3521
# 654

# %%
for token in text[0:10]:
  print (token)
# Out:
# T
# h
# e
#
# U
# n
# i
# t
# e
# d

# %%
for token in doc[0:10]:
  print (token)
# Out:
# The
# United
# States
# of
# America
# (
# U.S.A.
# or
# USA
# )

# %%
for token in text.split()[:10]:
  print (token)
# Out:
# The
# United
# States
# of
# America
# (U.S.A.
# or
# USA),
# commonly
# known

# %%
for sent in doc.sents:
  print (sent)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America.
# It consists of 50 states, a federal district, five major unincorporated territories, 326 Indian reservations, and some minor possessions.[j]
# At 3.8 million square miles (9.8 million square kilometers), it is the world's third- or fourth-largest country by total area.[d]
# The United States shares significant land borders with Canada to the north and Mexico to the south, as well as limited maritime borders with the Bahamas, Cuba, and Russia.[22] With a population of more than 331 million people, it is the third most populous country in the world.
# The national capital is Washington, D.C., and the most populous city is New York.
#
#
# Paleo-Indians migrated from Siberia to the North American mainland at least 12,000 years ago, and European colonization began in the 16th century.
# ...

# %%
sentence1=list(doc.sents)[0]
print (sentence1)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America.

# %%
for token in doc[:10]:
  print(token)
# Out:
# The
# United
# States
# of
# America
# (
# U.S.A.
# or
# USA
# )

# %%
token2=sentence1[2]
print(token2)
# Out:
# States

# %%
token2.text
# Out:
# 'States'

# %%
token2.left_edge
# Out:
# The

# %%
token2.right_edge
# Out:
# ,

# %%
token2.ent_type
# Out:
# 384

# %%
token2.ent_type_
# Out:
# 'GPE'

# %%
token2.ent_iob_
# Out:
# 'I'

# %%
token2.lemma_
# Out:
# 'States'

# %%
sentence1[12].lemma_
# Out:
# 'know'

# %%
print(sentence1[12])
# Out:
# known

# %%
token2.morph
# Out:
# Number=Sing

# %%
sentence1[12].morph
# Out:
# Aspect=Perf|Tense=Past|VerbForm=Part

# %%
token2.dep_
# Out:
# 'nsubj'

# %%
token2.lang_
# Out:
# 'en'

# %%
text="Mike enjoys playing football"
doc2=nlp(text)
print(doc2)
# Out:
# Mike enjoys playing football

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Mike PROPN nsubj
# enjoys VERB ROOT
# playing VERB xcomp
# football NOUN dobj

# %%
from spacy import displacy

# %%
displacy.render(doc2,style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c2d318f5bee54bd2908a08fa0f699c62-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mike</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">enjoys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
# ...

# %%
for ent in doc.ents:
  print (ent.text,ent.label_)
# Out:
# The United States of America GPE
# USA GPE
# the United States GPE
# U.S. GPE
# US GPE
# America GPE
# North America LOC
# 50 CARDINAL
# five CARDINAL
# 326 CARDINAL
# Indian NORP
# 3.8 million square miles QUANTITY
# 9.8 million square kilometers QUANTITY
# fourth ORDINAL
# The United States GPE
# Canada GPE
# Mexico GPE
# Bahamas GPE
# Cuba GPE
# more than 331 million CARDINAL
# third ORDINAL
# Washington GPE
# D.C. GPE
# New York GPE
# Paleo-Indians NORP
# Siberia LOC
# North American NORP
# at least 12,000 years ago DATE
# European NORP
# the 16th century DATE
# The United States GPE
# thirteen CARDINAL
# British NORP
# the East Coast LOC
# Great Britain GPE
# the American Revolutionary War ORG
# 1775–1783 CARDINAL
# the late 18th century DATE
# U.S. GPE
# North America LOC
# Native Americans NORP
# 1848 DATE
# the United States GPE
# United States GPE
# the second half of the 19th century DATE
# the American Civil War ORG
# Spanish NORP
# American War and EVENT
# ...

# %%
displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The United States of America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (U.S.A. or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ), commonly known as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
# ...

# %% [markdown]
# ###Word Vectors

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 65.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp=spacy.load("en_core_web_md")

# %%
with open ("/content/wiki_us.txt","r") as f:
  text=f.read()

# %%
doc =nlp(text)
sentence1=list(doc.sents)[0]
print(sentence1)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America.

# %%
import numpy as np
your_word="country"
ms=nlp.vocab.vectors.most_similar(
    np.asarray([nlp.vocab.vectors[nlp.vocab.strings[your_word]]]),n=10
)
words=[nlp.vocab.strings[w] for w in ms[0][0]]
distances= ms[2]
print(words)
# Out:
# ['inner-city', 'anti-poverty', 'SLUMS', 'Socioeconomic', 'Divides', 'INTERSECT', 'drop-out', 'dropout', 'handicaps', 'suburb']

# %%
doc1=nlp("I like salty fries and hamburgers.")
doc2=nlp("Fast food tastes very good.")

# %%
print(doc1,"<=>",doc2,doc1.similarity(doc2))
# Out:
# I like salty fries and hamburgers. <=> Fast food tastes very good. 0.8015960454940796

# %%
doc3=nlp("The empire state building is in new york.")

# %%
print(doc1,"<=>",doc3,doc1.similarity(doc3))
# Out:
# I like salty fries and hamburgers. <=> The empire state building is in new york. 0.5638526678085327

# %%
doc4=nlp("I enjoy oranges.")
doc5=nlp("I enjoy apples.")

# %%
print(doc4,"<=>",doc5,doc4.similarity(doc5))
# Out:
# I enjoy oranges. <=> I enjoy apples. 0.9522808194160461

# %%
doc6=nlp("I enjoy burgers.")

# %%
print (doc4,"<->",doc6,doc4.similarity(doc6))
# Out:
# I enjoy oranges. <-> I enjoy burgers. 0.8937570452690125

# %%
french_fries=doc1[2:4]
burgers=doc1[5]
print (french_fries,"<=>",burgers,french_fries.similarity(burgers))
# Out:
# salty fries <=> hamburgers 0.5733411312103271

# %% [markdown]
# ###Spacy Pipelines

# %%
nlp=spacy.blank("en")

# %%
nlp.add_pipe("sentencizer")

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#    'requires': [],
#    'scores': ['sents_f', 'sents_p', 'sents_r'],
#    'retokenizes': False}},
#  'problems': {'sentencizer': []},
#  'attrs': {'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []},
#   'doc.sents': {'assigns': ['sentencizer'], 'requires': []}}}

# %%
nlp2=spacy.load("en_core_web_sm")

# %%
nlp2.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc',
#     'pos_acc',
#     'tag_micro_p',
#     'tag_micro_r',
#     'tag_micro_f'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
# ...

# %% [markdown]
# ###Using Spacy's Entity Ruler

# %%
nlp=spacy.load("en_core_web_sm")
text="West Chesterfieldville was referenced in Mr. Deeds"

# %%
doc=nlp(text)

# %%
for ent in doc.ents:
  print (ent.text,ent.label_)
# Out:
# West Chesterfieldville GPE
# Deeds PERSON

# %%
ruler=nlp.add_pipe("entity_ruler")

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc',
#     'pos_acc',
#     'tag_micro_p',
#     'tag_micro_r',
#     'tag_micro_f'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
# ...

# %%
nlp3=spacy.load("en_core_web_sm")

# %%
ruler=nlp3.add_pipe("entity_ruler",before="ner")

# %%
patterns=[
    {"label":"FILM","pattern":"Mr. Deeds"}
]

# %%
ruler.add_patterns(patterns)

# %%
doc=nlp3(text)

# %%
for ent in doc.ents:
  print (ent.text,ent.label_)
# Out:
# West Chesterfieldville GPE
# Mr. Deeds FILM

# %% [markdown]
# ###Spacy Matcher

# %%
import spacy
from spacy.matcher import Matcher

# %%
nlp=spacy.load("en_core_web_sm")

# %%
matcher=Matcher(nlp.vocab)
pattern=[{"LIKE_EMAIL":True}]
matcher.add("EMAIL_ADDRESS",[pattern])

# %%
doc=nlp("This is an email adress: bukunmbalogun9@gmail.com")
matches=matcher(doc)

# %%
print(matches)
# Out:
# [(16571425990740197027, 6, 7)]

# %%
print(nlp.vocab[matches[0][0]].text)
# Out:
# EMAIL_ADDRESS

# %%
with open("/content/wiki_mlk.txt","r") as f:
  text=f.read()

# %%
print(text)
# Out:
# Martin Luther King Jr. (born Michael King Jr.; January 15, 1929 – April 4, 1968) was an American Baptist minister and activist who became the most visible spokesman and leader in the American civil rights movement from 1955 until his assassination in 1968. King advanced civil rights through nonviolence and civil disobedience, inspired by his Christian beliefs and the nonviolent activism of Mahatma Gandhi. He was the son of early civil rights activist and minister Martin Luther King Sr.
#
# ...

# %%
nlp=spacy.load("en_core_web_sm")

# %%
matcher=Matcher(nlp.vocab)
pattern=[{"POS":"PROPN"}]
matcher.add("PROPER_NOUN",[pattern])
doc=nlp(text)
matches=matcher(doc)
print (len(matches))
for match in matches[:10]:
  print (match,doc[match[1]:match[2]])
# Out:
# 101
# (451313080118390996, 0, 1) Martin
# (451313080118390996, 1, 2) Luther
# (451313080118390996, 2, 3) King
# (451313080118390996, 3, 4) Jr.
# (451313080118390996, 6, 7) Michael
# (451313080118390996, 7, 8) King
# (451313080118390996, 8, 9) Jr.
# (451313080118390996, 10, 11) January
# (451313080118390996, 15, 16) April
# (451313080118390996, 49, 50) King

# %%
matcher=Matcher(nlp.vocab)
pattern=[{"POS":"PROPN","OP":"+"}]
matcher.add("PROPER_NOUN",[pattern],greedy='LONGEST')
doc=nlp(text)
matches=matcher(doc)
matches.sort(key=lambda x:x[1])
print (len(matches))
for match in matches[:10]:
  print (match,doc[match[1]:match[2]])
# Out:
# 60
# (451313080118390996, 0, 4) Martin Luther King Jr.
# (451313080118390996, 6, 9) Michael King Jr.
# (451313080118390996, 10, 11) January
# (451313080118390996, 15, 16) April
# (451313080118390996, 49, 50) King
# (451313080118390996, 69, 71) Mahatma Gandhi
# (451313080118390996, 83, 88) Martin Luther King Sr.
# (451313080118390996, 89, 90) King
# (451313080118390996, 113, 114) King
# (451313080118390996, 117, 118) Montgomery

# %%
matcher=Matcher(nlp.vocab)
pattern=[{"POS":"PROPN","OP":"+"},{"POS":"VERB"}]
matcher.add("PROPER_NOUN",[pattern],greedy='LONGEST')
doc=nlp(text)
matches=matcher(doc)
matches.sort(key=lambda x:x[1])
print (len(matches))
for match in matches[:10]:
  print (match,doc[match[1]:match[2]])
# Out:
# 7
# (451313080118390996, 49, 51) King advanced
# (451313080118390996, 89, 91) King participated
# (451313080118390996, 113, 115) King led
# (451313080118390996, 167, 169) King helped
# (451313080118390996, 247, 252) Director J. Edgar Hoover considered
# (451313080118390996, 322, 324) King won
# (451313080118390996, 485, 488) United States beginning

# %%
import json
with open ("/content/alice.json","r") as f:
  data =json.load(f)

# %%
text=data[0][2][0]
print (text)
# Out:
# Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, `and what is the use of a book,' thought Alice `without pictures or conversation?'

# %%
matcher=Matcher(nlp.vocab)
pattern=[{"ORTH":"`"},
         {"IS_ALPHA":True,"OP":"+"},
         {"IS_PUNCT":True,"OP":"*"},
         {"ORTH":"'"}
         ]
matcher.add("PROPER_NOUN",[pattern],greedy='LONGEST')
doc=nlp(text)
matches=matcher(doc)
matches.sort(key=lambda x:x[1])
print (len(matches))
for match in matches[:10]:
  print (match,doc[match[1]:match[2]])
# Out:
# 2
# (451313080118390996, 47, 58) `and what is the use of a book,'
# (451313080118390996, 60, 67) `without pictures or conversation?'

# %%
speak_lemmas=["think","say"]
matcher=Matcher(nlp.vocab)
pattern=[{"ORTH":"`"},
         {"IS_ALPHA":True,"OP":"+"},
         {"IS_PUNCT":True,"OP":"*"},
         {"ORTH":"'"},
         {"POS":"VERB","LEMMA":{"IN":speak_lemmas}}
         ]
matcher.add("SPEAKING_VERBS", [pattern], greedy="LONGEST")
doc=nlp(text)
matches=matcher(doc)
matches.sort(key=lambda x:x[1])
print (len(matches))
for match in matches[:10]:
  print (match,doc[match[1]:match[2]])
# Out:
# 1
# (2343599644821389889, 47, 59) `and what is the use of a book,' thought

# %%
speak_lemmas=["think","say"]
matcher=Matcher(nlp.vocab)
pattern=[{"ORTH":"`"},
         {"IS_ALPHA":True,"OP":"+"},
         {"IS_PUNCT":True,"OP":"*"},
         {"ORTH":"'"},
         {"POS":"VERB","LEMMA":{"IN":speak_lemmas}},
         {"POS":"PROPN","OP":"+"}
         ]
matcher.add("SPEAKING_VERBS", [pattern], greedy="LONGEST")
doc=nlp(text)
matches=matcher(doc)
matches.sort(key=lambda x:x[1])
print (len(matches))
for match in matches[:10]:
  print (match,doc[match[1]:match[2]])
# Out:
# 1
# (2343599644821389889, 47, 60) `and what is the use of a book,' thought Alice

# %%
speak_lemmas=["think","say"]
matcher=Matcher(nlp.vocab)
pattern=[{"ORTH":"`"},
         {"IS_ALPHA":True,"OP":"+"},
         {"IS_PUNCT":True,"OP":"*"},
         {"ORTH":"'"},
         {"POS":"VERB","LEMMA":{"IN":speak_lemmas}},
         {"POS":"PROPN","OP":"+"},
         {"ORTH":"`"},
         {"IS_ALPHA":True,"OP":"+"},
         {"IS_PUNCT":True,"OP":"*"},
         {"ORTH":"'"}
         ]
matcher.add("SPEAKING_VERBS", [pattern], greedy="LONGEST")
doc=nlp(text)
matches=matcher(doc)
matches.sort(key=lambda x:x[1])
print (len(matches))
for match in matches[:10]:
  print (match,doc[match[1]:match[2]])
# Out:
# 1
# (2343599644821389889, 47, 67) `and what is the use of a book,' thought Alice `without pictures or conversation?'

# %%
for text in data[0][2]:
 # text=text.replace("`","'")
  doc=nlp(text)
  matches=matcher(doc)
  matches.sort(key=lambda x:x[1])
  for match in matches[:10]:
    print (match,doc[match[1]:match[2]])
# Out:
# (2343599644821389889, 47, 67) `and what is the use of a book,' thought Alice `without pictures or conversation?'

# %%
speak_lemmas = ["think", "say"]
text = data[0][2][0].replace( "`", "'")
matcher = Matcher(nlp.vocab)
pattern1 = [{'ORTH': "'"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': "'"}, {"POS": "VERB", "LEMMA": {"IN": speak_lemmas}}, {"POS": "PROPN", "OP": "+"}, {'ORTH': "'"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': "'"}]
pattern2 = [{'ORTH': "'"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': "'"}, {"POS": "VERB", "LEMMA": {"IN": speak_lemmas}}, {"POS": "PROPN", "OP": "+"}]
pattern3 = [{"POS": "PROPN", "OP": "+"},{"POS": "VERB", "LEMMA": {"IN": speak_lemmas}}, {'ORTH': "'"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': "'"}]
matcher.add("PROPER_NOUNS", [pattern1, pattern2, pattern3], greedy='LONGEST')
for text in data[0][2]:
    text = text.replace("`", "'")
    doc = nlp(text)
    matches = matcher(doc)
    matches.sort(key = lambda x: x[1])
    print (len(matches))
    for match in matches[:10]:
        print (match, doc[match[1]:match[2]])
# Out:
# 1
# (3232560085755078826, 47, 67) 'and what is the use of a book,' thought Alice 'without pictures or conversation?'
# 0
# 0
# 0
# 0
# 0
# 1
# (3232560085755078826, 0, 6) 'Well!' thought Alice
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# (3232560085755078826, 57, 68) 'which certainly was not here before,' said Alice
# 0
# 0

# %% [markdown]
# ###Custom Component in Spacy

# %%
nlp=spacy.load("en_core_web_sm")
doc=nlp("Britain is a place. Mary is a doctor.")

# %%
for ent in doc.ents:
  print(ent.text,ent.label_)
# Out:
# Britain GPE
# Mary PERSON

# %%
from spacy.language import Language

# %%
@Language.component("remove_gpe")
def remove_gpe(doc):
    original_ents = list(doc.ents)
    for ent in doc.ents:
        if ent.label_ == "GPE":
            original_ents.remove(ent)
    doc.ents = original_ents
    return (doc)

# %%
nlp.add_pipe("remove_gpe")
# Out:
# <function __main__.remove_gpe(doc)>

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc',
#     'pos_acc',
#     'tag_micro_p',
#     'tag_micro_r',
#     'tag_micro_f'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
# ...

# %%
doc = nlp("Britain is a place. Mary is a doctor.")
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# Mary PERSON

# %% [markdown]
# Using RegEx in spacy

# %%
import re

# %%
import re

text = "Paul Newman was an American actor, but Paul Hollywood is a British TV Host. The name Paul is quite common."

pattern = r"Paul [A-Z]\w+"

matches = re.finditer(pattern, text)

for match in matches:
    print (match)
# Out:
# <re.Match object; span=(0, 11), match='Paul Newman'>
# <re.Match object; span=(39, 53), match='Paul Hollywood'>

# %%
import spacy
from spacy.tokens import Span

# %%
text = "Paul Newman was an American actor, but Paul Hollywood is a British TV Host. The name Paul is quite common."
pattern = r"Paul [A-Z]\w+"

# %%
nlp = spacy.blank("en")
doc = nlp(text)

# %%
original_ents = list(doc.ents)

# %%
mwt_ents = []
for match in re.finditer(pattern, doc.text):
    start, end = match.span()
    span = doc.char_span(start, end)
    if span is not None:
        mwt_ents.append((span.start, span.end, span.text))

# %%
for ent in mwt_ents:
    start, end, name = ent
    per_ent = Span(doc, start, end, label="PERSON")
    original_ents.append(per_ent)

# %%
doc.ents = original_ents

# %%
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# Paul Newman PERSON
# Paul Hollywood PERSON

# %%
import spacy

text = "Paul Newman was an American actor, but Paul Hollywood is a British TV Host."
pattern = r"Hollywood"

nlp = spacy.load("en_core_web_sm")

doc = nlp(text)
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# Paul Newman PERSON
# American NORP
# Paul Hollywood PERSON
# British NORP

# %%
from spacy.util import filter_spans
filtered = filter_spans(original_ents)
doc.ents = filtered
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# Paul Newman PERSON
# Paul Hollywood PERSON

# %% [markdown]
# ###Stocks Project using Spacy

# %%
import spacy
import pandas as pd

# %%
df=pd.read_csv("/content/stocks.tsv",sep="\t")

# %%
df
# Out:
#      Symbol              CompanyName                          Industry  \
# 0         A     Agilent Technologies    Life Sciences Tools & Services
# 1        AA                    Alcoa                   Metals & Mining
# 2       AAC         Ares Acquisition                   Shell Companies
# 3      AACG    ATA Creativity Global     Diversified Consumer Services
# 4      AADI          Aadi Bioscience                   Pharmaceuticals
# ...     ...                      ...                               ...
# 5874   ZWRK       Z-Work Acquisition                   Shell Companies
# 5875     ZY                 Zymergen                         Chemicals
# 5876   ZYME                Zymeworks                     Biotechnology
# 5877   ZYNE  Zynerba Pharmaceuticals                   Pharmaceuticals
# 5878   ZYXI                    Zynex  Health Care Equipment & Supplies
#
#      MarketCap
# 0       53.65B
# 1        9.25B
# 2        1.22B
# 3       90.35M
# 4      104.85M
# ...        ...
# ...

# %%
symbols=df.Symbol.tolist()
companies=df.CompanyName.tolist()
print(symbols[:10])
# Out:
# ['A', 'AA', 'AAC', 'AACG', 'AADI', 'AAIC', 'AAL', 'AAMC', 'AAME', 'AAN']

# %%
nlp=spacy.blank("en")
ruler=nlp.add_pipe("entity_ruler")
patterns=[]
for symbol in symbols:
  patterns.append({"label":"STOCK","pattern":symbol})
for company in companies:
  patterns.append({"label":"COMPANY","pattern":company})
ruler.add_patterns(patterns)

# %%
text="""
Apple reported strong quarterly earnings as investors continued to watch AAPL closely.
Microsoft also gained attention after MSFT announced new developments in its cloud business.
Tesla shares moved higher after TSLA reported strong vehicle deliveries.
Amazon remained one of the most discussed companies on Wall Street, while AMZN trading volume increased.
Alphabet continued to attract investors as GOOG and GOOGL shares were actively traded.
Meta Platforms saw increased interest from investors, with META shares moving during the trading session.
NVIDIA remained a major technology stock as NVDA continued to receive attention from the market.
Netflix reported strong subscriber growth, pushing NFLX into focus among technology investors.
Intel faced pressure during trading as INTC shares declined.
Bank of America remained active in the financial sector, while BAC shares were closely watched.
Coca-Cola continued to trade steadily as investors followed KO.
Walmart reported positive retail results, and WMT shares attracted significant trading activity.
JPMorgan Chase remained one of the most closely watched financial companies, with JPM shares trading actively.
Johnson & Johnson continued to attract investors, while JNJ remained an important healthcare stock.
Nike experienced changes in its share price as NKE investors reacted to the latest company news.
"""

# %%
doc=nlp(text)
for ent in doc.ents:
  print(ent.text,ent.label_)
# Out:
# Apple COMPANY
# AAPL STOCK
# Microsoft COMPANY
# MSFT STOCK
# Tesla COMPANY
# TSLA STOCK
# Amazon COMPANY
# AMZN STOCK
# Alphabet COMPANY
# GOOG STOCK
# GOOGL STOCK
# NVIDIA COMPANY
# NVDA STOCK
# Netflix COMPANY
# NFLX STOCK
# Intel COMPANY
# INTC STOCK
# Bank of America COMPANY
# BAC STOCK
# Coca-Cola COMPANY
# KO STOCK
# Walmart COMPANY
# WMT STOCK
# JPMorgan Chase COMPANY
# JPM STOCK
# Johnson & Johnson COMPANY
# JNJ STOCK
# Nike COMPANY
# NKE STOCK

# %%
from spacy import displacy

# %%
displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  reported strong quarterly earnings as investors continued to watch
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAPL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
#  closely.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
# ...
